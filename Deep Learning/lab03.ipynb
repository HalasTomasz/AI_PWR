# %% [markdown]
# # Wstęp
#
# Na poprzednich zajęciach nauczyłeś(aś) się jak skonstruować od zera podstawową komórkę sieci neuronowej - Perceptron. Na tych zajęciach przejdziemy już do wykorzystywania bardziej zaawansowanych funkcji PyTorcha, które przydają się na codzień do konstruowania sieci neuronowych.
#
# ## Cel ćwiczenia
#
# Celem ćwiczenia jest zapoznanie z podstawowymi funkcjami biblioteki PyTorch do tworzenia i uczenia sieci neuronowych a w szczególności z:
# *   Automatycznym liczeniem gradientów i grafem obliczeniowym (autograd)
# *   Algorytmami off-line, on-line a także pojęciem mini-batch
# *   Algorytmami optymalizacji sieci neuronowych
# *   Liczeniem wartości fuknkcji straty
# *   Przekształceniami nieliniowymi
# *   Modułem `torch.nn`
#
# ## Warunki zaliczenia
#
# W celu zaliczenia ćwiczeń należy uzupełnić wszystkie brakujące elementu kodu, wykonać wszystkie polecenia i wyuczyć model.

# %%
import math
import warnings
from typing import Tuple

import torch
import torch.nn.functional as F
import torch.utils.data
from sklearn.model_selection import train_test_split
from sklearn.datasets import load_iris
from torch import nn
from torch import optim
from torch.utils.data import TensorDataset, DataLoader

assert torch.cuda.is_available(), "Uruchom środowisko wykonawcze na GPU"

# %% [markdown]
# # Autograd - automatyczne liczenie gradientów
#
# Na poprzednich laboratoriach implementowałeś(aś) funkcję wstecznej propagacji. W tym celu liczyłaś(eś) pochodne (gradienty). Przyjrzyjmy się najpierw funkcji
# $$f(x, y) = 3x^2 + y^3$$
# Możemy tę funkcję różniczkować po dwóch zmiennych: $x$ i $y$:
# $$\frac{\partial f}{\partial x} = 6x$$
#
# $$\frac{\partial f}{\partial y} = 3y^2$$
#
# Jeżeli funkcję $f(x,y)$ złożymy z funkcją $g(x) = x^2$ tworząc funkcję $h(x, y) = f(g(x), y)$ to z **reguły łańcuchowej** pochodna takiej funkcji wyniesie:
#
# $$\frac{\partial h}{\partial x} = \frac{\partial f}{\partial g} \frac{\partial g}{\partial x} = (6 (x^2)) (2 x) = 12 x^3$$
#
# Tego typu obliczenia przy wielu warstwach sieci (a więc przy wielu złożeniach funkcji liniowych i nieliniowych) stają się mocno skomplikowane. Na szczęście PyToch dostarcza `torch.autograd` - silnik do zaumatyzowanego liczenia gradientów. Jak on działa? Najpierw zdefiniujmy wektory $\mathbf x$ i $\mathbf y$.

# %%
x = torch.tensor([0., 1., 5.], requires_grad=True)
y = torch.tensor([8., 2., 4.], requires_grad=True)

# %% [markdown]
# Zauważ, że tworząc tensor przekazaliśmy parametr `requires_grad=True`. Sprawia on, że wszystkie operacje dokonane na tym tensorze są śledzone i tensor wynikowy będzie "pamiętał" przy użyciu jakiej operacji powstał. Policzmy naszą funkcję $f( \mathbf x, \mathbf y)$ dla tych tensorów.

# %%
z = 3*x**2 + y**3
z
# Out:
# tensor([512.,  11., 139.], grad_fn=<AddBackward0>)

# %% [markdown]
# Jak widać uzyskany tensor ma także zapisany parametr `grad_fn=<AddBackward0>`, czyli że powstał z dodania dwóch tensorów - dodawanie jest ostatnią operacją, która zostałą wykonana, żeby otrzymać ten tensor. Dokonajmy propagacji wstecznej w celu policzenia gradientów.

# %%
grad_tensors = torch.tensor([1., 1., 1.])
z.backward(grad_tensors)
print(x.grad == 6*x)
print(y.grad == 3*y**2)
# Out:
# tensor([True, True, True])
# tensor([True, True, True])

# %% [markdown]
# Na razie nie przejmuj się tym za co odpowiada `grad_tensors`. Policzmy wartość funkcji $h$.

# %%
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
print(x.grad == 12*(x**3))
# Out:
# tensor([   0.,   18., 1530.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)
# tensor([ True, False, False])

# %% [markdown]
# Nie zgadzają nam się wartości. Wynika to z kolejnej właśności pytorchowego autograda - gradienty w tensorach są **akumulowane**. Jak wykonasz powyższą komórkę wielekrotnie to zobaczysz że wartości `x.grad` rosną dokładnie o $12x_i^3$ po każdym wykonaniu. Akumulacja gradientów jest przydatna w niektórych architekturach sieci neuronowych. Dlatego też trzeba *explicite* wyzerować gradienty.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.backward(grad_tensors)
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Ok, powróćmy teraz do `grad_tensors` - co to jest? Otóż autograd jest silnikiem, który służy do wyliczania **macierzy Jacobiego**, tj. pochodnych pierwszego rzędu funkcji, których składowymi są funkcje rzeczywiste.
#
# $$f = (f_1, f_2, \ldots, f_m)$$
# $$\mathbf x = (x_1, x_2, \ldots, x_n)$$
#
# $$\mathbf J = \begin{bmatrix}
#  \dfrac{\partial f_1}{\partial x_1} & \cdots & \dfrac{\partial f_1}{\partial x_n} \\
#  \vdots & \ddots & \vdots \\
#  \dfrac{\partial f_m}{\partial x_1} & \cdots & \dfrac{\partial f_m}{\partial x_n}
# \end{bmatrix}$$
#
# Konkretnie patrząc na przykład z tensorem $a$ macierz Jacobiego wygląda tak:
# $$\mathbf J_a = \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} \\
#   \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_2}{\partial x_3} \\
#    \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}$$
#
# Następnie `grad_tensors` ($\mathbf z$) mnożymy przez transpozycję tej macierzy (ang. *Jacobian-vector product*).
#
# $$\mathbf z \mathbf{J}_a^T = \begin{bmatrix} 1 & 1 & 1 \end{bmatrix}
#
# \begin{bmatrix}
#  \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_1} & \dfrac{\partial a_3}{\partial x_1} \\
#   \dfrac{\partial a_1}{\partial x_2} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_2} \\
#    \dfrac{\partial a_1}{\partial x_3} & \dfrac{\partial a_2}{\partial x_3} & \dfrac{\partial a_3}{\partial x_3} \\
# \end{bmatrix}
#
# = \begin{bmatrix} 1\dfrac{\partial a_1}{\partial x_1} + 1\dfrac{\partial a_1}{\partial x_2} + 1\dfrac{\partial a_1}{\partial x_3} & 1\dfrac{\partial a_2}{\partial x_1} + 1\dfrac{\partial a_2}{\partial x_2} + 1\dfrac{\partial a_2}{\partial x_3} & 1\dfrac{\partial a_3}{\partial x_1} + 1\dfrac{\partial a_3}{\partial x_2} + 1\dfrac{\partial a_3}{\partial x_3} \end{bmatrix}
#
# = \begin{bmatrix} 12(0)^3 + 0 + 0 & 0 + 12(1)^3 + 0 & 0 + 0 + 12(5)^3 \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix}$$
#
# Uzyskujemy te same gradienty co policzyliśmy dla wektora $\mathbf x$. Zamiast przekazywać wektor jedynek do `backward()`, można najpierw policzyć sumę wektora $\mathbf a$ a potem wykonać propagację wsteczną.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.sum().backward()
print(x.grad)
print(12*(x**3))
assert (x.grad == 12*(x**3)).all()
# Out:
# tensor([   0.,   12., 1500.])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# Wtedy pamiętając o tym, że pochodna sumy to suma pochodnych ($(f(x) + g(x))' = f'(x) + g'(x)$):
#
# $$\begin{bmatrix}
#  \dfrac{\partial a}{\partial x_1} & \dfrac{\partial a}{\partial x_2} & \dfrac{\partial a}{\partial x_3}
# \end{bmatrix} = \begin{bmatrix} \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_1} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_2} & \dfrac{\partial (a_1 + a_2 + a_3)}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} + \dfrac{\partial a_2}{\partial x_1} + \dfrac{\partial a_3}{\partial x_1} & \dfrac{\partial a_1}{\partial x_2} + \dfrac{\partial a_2}{\partial x_2} + \dfrac{\partial a_3}{\partial x_2} & \dfrac{\partial a_1}{\partial x_3} + \dfrac{\partial a_2}{\partial x_3} + \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} = \begin{bmatrix} \dfrac{\partial a_1}{\partial x_1} & \dfrac{\partial a_2}{\partial x_2} & \dfrac{\partial a_3}{\partial x_3} \end{bmatrix} =  \begin{bmatrix} 0 & 12 & 1500 \end{bmatrix} $$
#
# Zatem po co w ogóle ten wektor? Otóż służy on do przekazywania wektora gradientu funkcji straty ($\dfrac{\partial \mathbf{loss}}{\partial \mathbf w}$). Dzięki temu możemy mieć wpływ na to jaką poprawkę trzeba wykonać na danym wektorze (np. z parametrami modelu) względem tego jak bardzo mocno model pomylił się na danych uczących.

# %%
x.grad.data.zero_()
a = 3*(x**2)**2 + y**3
a.backward(torch.tensor([0., 0.3, -0.4]))
print(x.grad)
print(12*(x**3))
# Out:
# tensor([   0.0000,    3.6000, -600.0001])
# tensor([   0.,   12., 1500.], grad_fn=<MulBackward0>)

# %% [markdown]
# ## Graf obliczeniowy
#
# To wszystko jest możliwe dzięki temu, że autograd tworzy **acykliczny skierowany graf obilczeniowy**. Gdzie go przechowuje? Spójrzmy jeszcze raz na nasz wektor $\mathbf a$.

# %%
print(a)
print(a.grad_fn.next_functions)
# Out:
# tensor([ 512.,   11., 1939.], grad_fn=<AddBackward0>)
# ((<MulBackward0 object at 0x7f1b042da670>, 0), (<PowBackward0 object at 0x7f1b04177790>, 0))

# %% [markdown]
# Obiekt a ma pole `grad_fn` a ono ma pole `next_functions`. Widzimy, że $\mathbf a$ powstało z przemnożenia dwóch tensorów, gdzie pierwszy tensor był wynikiem mnożenia a drugi - potęgowania. A więc na razie wiemy, że `a = (_*_) + (_**_)`. I kolejno przechodząc po tym grafie możemy dalej odkrywać jego strukturę i jaka droga skonstruowania $\mathbf a$ się za nim kryje.

# %%
print(a.grad_fn.next_functions[0][0].next_functions) # a = ((_**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions) # a = (((_**_))**_))*_) + (_**_)
print(a.grad_fn.next_functions[0][0].next_functions[0][0].next_functions[0][0].next_functions) # a = (((x**_))**_))*_) + (_**_)
print()
print(a.grad_fn.next_functions[1][0].next_functions) # a = (((x**_))**_))*_) + (y**_)
# Out:
# ((<PowBackward0 object at 0x7f1a557e61f0>, 0), (None, 0))
# ((<PowBackward0 object at 0x7f1a557e66a0>, 0),)
# ((<AccumulateGrad object at 0x7f1a557e6ca0>, 0),)
#
# ((<AccumulateGrad object at 0x7f1a557e6550>, 0),)

# %% [markdown]
# Po chwilii analizy można dostrzec że ta strutura odpowiada obliczeniu tensora $a$ ze wzoru $3(\mathbf x^2)^2 + \mathbf y^3$.
#
# Jeszcze warto wspomnieć o tym, że PyTorch śledzi to dla których tensorów trzeba tworzyć ten graf a dla których nie. Dlatego też jeżeli w operacjach użyjemy tensora, który "wymaga gradientu" (`requires_grad=True`) to uzyskamy tensor "wymagający gradientu":

# %%
x = torch.tensor([1., 2., 3.])
y = torch.tensor([6., 7., 8.])
z = torch.tensor([9., 7., 8.], requires_grad=True)
print((2*x + 3**y).requires_grad)
print((2*x + 3**y + z).requires_grad)
# Out:
# False
# True

# %% [markdown]
# # Refactoring kodu z laboratorium 2
#
# W tej części laboratorium dokonasz refaktoringu kodu z laboratorium drugiego z wykorzystaniem gotowych rozwiązań w bibliotece `torch` a w szczególności w `torch.nn`. Najpierw zacznijmy od załadowania zbioru danych i podzielenia go na zbiór uczący i testowy.

# %%
X, y = load_iris(return_X_y=True)

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.4, random_state=1, stratify=y)

X_train = torch.tensor(X_train).float().cuda()
X_test = torch.tensor(X_test).float().cuda()
y_train = torch.tensor(y_train).cuda()
y_test = torch.tensor(y_test).cuda()

y_test
# Out:
# tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1, 1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0,
#         0, 1, 2, 1, 1, 1, 2, 1, 0, 0, 1, 1], device='cuda:0')

# %% [markdown]
# ## `nn.Module` oraz `CrossEntropyLoss`
#
# Na poprzednich laboratoriach w tym miejscu implementowaliśmy funkcję sigmoid, inicjalizację parametrów oraz propagację w przód i wsteczną. Tym razem nie będzie trzeba tego robić, jednakże zdefiniujesz architekturę sieci przy użyciu modułu `torch.nn`.
#
# ***Zaimplementuj*** klasę Perceptron - klasę dziedziczącą po `nn.Module` z jedną warstwą transformacji liniowej (Perceptrona, [`torch.nn.Linear`](https://pytorch.org/docs/stable/generated/torch.nn.Linear.html)). Na razie ***pomiń*** transformację nieliniową (np. sigmoid).

# %%
class Perceptron(nn.Module):
    def __init__(self, in_dim: int, out_dim: int):
        super().__init__()
        self.net = nn.Linear(in_dim, out_dim) # Użyj nn.Linear

    def forward(self, x: torch.Tensor):
        return self.net(x)

# %% [markdown]
# Wspominmy tylko, że można nadal używać `torch.nn` i nie wykorzystywać gotowych warstw sieci tylko samemu implementować operacje na tensorach:
#
# ```
# class Perceptron(nn.Module):
#     def __init__(self, in_dim: int, out_dim: int):
#         super().__init__()
#         self.weights = nn.Parameter(
#           torch.randn(in_dim, out_dim) / math.sqrt(in_dim)
#         )
#         self.bias = nn.Parameter(torch.zeros(out_dim))
#
#     def forward(self, xb: torch.Tensor):
#         return xb @ self.weights + self.bias
# ```
# ***Przetestuj*** poprawność swojej implementacji.

# %%
model = Perceptron(X_train.shape[1], 3).cuda()
y_pred_0 = model(X_train[0])
print(y_pred_0)

assert isinstance(y_pred_0, torch.cuda.FloatTensor)
assert len(y_pred_0) == 3
# Out:
# tensor([-1.1996, -1.6242, -0.4332], device='cuda:0', grad_fn=<AddBackward0>)

# %% [markdown]
# Wykorzystanie `nn.Linear` nie tylko odciążyło nas z implementacji operacji na tensorasch, ale także z inicjalizacji paprametrów modelu - inicjalizacja parametrów jest domyślnie implementowana przez daną wartstwę. Jeżeli uruchomisz powyższy kod wielokrotnie to zauważysz, że za każdym razem otrzymujesz inny tensor wyjściowy. Wynika to z tego, że początkowe parametry modelu są domyślnie **losowane**. Oznacza to, że proces uczenia będzie **niedeterministryczny** - każde uruchomienie da inny wynik parametrów, które model się nauczy.
#
# Pozostało jeszcze dodanie nieliniowej transformacji do sieci, ale nie będziemy tego robić. Dodatkowo zamiast tworzyć osobny klasifikator na klasę, zastosujemy jeden klasyfikator. W tym celu zmieniemy funkcję kosztu. Do klasyfikacji wieloklasowej wykorzystamy funkcję **straty krzyżowej entropii**.
#
# $\text{loss} = -\frac{1}{N}\sum_{i}^{N}\log(\text{softmax}(x_{i}){y_{i}}) $, gdzie $N$ oznacza liczbę przypadków, $x_{i}$ wyjście z ostatniej warstwy $i$-tej instancji, $y_{i}$ klasę $i$-tej instancji.
#
# **Softmax** jest przekstałceniem nielinowym powszechnie używanym jako ostatnia warstwa sieci neuronowej służącej do klasyfikacji. Jej mocną stroną jest to, że suma wszystkich elementów tensora będących na jej wyjściu wynosi $1$. Dzięki temu możemy wyjście sieci interpretować jako przypisanie pseudoprawdopodbieństwa dla klasyfikacji dla danej próbki.
#
# Dla danego wektora $\mathbf x = (x_1, x_2, \ldots, x_i, \ldots, x_C)$ funkcja Softmax jest zdefiniowana jako:
# $\text{Softmax}(x_{i}) = \frac{\exp(x_{i})}{\sum_{j}^{C} \exp(x_{j})}$, gdzie $C$ oznacza liczbę klas.
#
# W tym zadaniu nie będziemy implementować tych funkcji samemu tylko wykorzystamy gotową implementację w bibliotece torch. Implementację znajdziemy w [`torch.nn.CrossEntropyLoss`](https://pytorch.org/docs/stable/generated/torch.nn.CrossEntropyLoss.html). Przyjmuje ona "surowe" wartości, dlatego że oblicza również funkcję **LogSoftmax**. Alternatywnie możemy nałożyć funkcję aktywacji LogSoftmax z modułu [`torch.nn.LogSoftmax`](https://pytorch.org/docs/stable/generated/torch.nn.LogSoftmax.html) i obliczyć negatywny logarytm funkcji wiarygodności (ang. *negative log likelihood*) [`torch.nn.NLLLoss`](https://pytorch.org/docs/stable/generated/torch.nn.NLLLoss.html#torch.nn.NLLLoss). `torch.nn.NLLLoss` nie wykonuje operacji logarytmowania tylko oczekuje zlogarytmowanego wejścia.
#
# **LogSoftmax** wykorzystany jest tutaj nieprzypadkowo. Funkcja softmax w oryginalnej postaci nie jest odparna na wystąpienie niestabilności numerycznych. W przypadku liczenia entropii krzyżowej możemy wykorzystać skalę logarytmiczną do przeprowadzenia operacji. Dzięki przenesieniu obliczania logarytmu do funkcji Softmax możemy zastąpić dzielenie na różnicę logarytmów. czyli zamiast powyższej definicji funkcja LogSoftmax przyjmuję następującą postać:
#
# $\text{LogSoftmax}(x_{i}) = x_{i} - log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$
#
# Dodatkowo stosowany jest także trik polegający na zastąpieniu operacji $log \bigg({\sum_{j}^{C} \exp(x_{j})}\bigg)$ operacją **LogSumExp**, zdefiniowaną jako
#
# $\text{LogSumExp}(\mathbf x) = \max(\mathbf x) + log \bigg({\sum_{j}^{C} \exp(x_{j} - \max(\mathbf x))}\bigg)$.
#
# Pozwala to pozbyć się dużych wartości $x_{j}$ podczas obliczania $\exp$.

# %% [markdown]
# ## Algorytmy online i offline (`DataLoader`)
#
# Na poprzednich zajęciach zaimplementowałaś(eś) **algorytm offline** (alternatywnie batchowy lub deterministyczny, ang. *offline*, *batch*, *deterministic*) tzn. taki, który przetwarza od razu wszystkie dane. Jednakże implementując sieci neuronowe tworzymy często algorytmy **online** (alternatywnie stochastyczne, ang. *online*, *stochastic*), które przetwarzają dane w "kawałkach" lub wręcz mogą dostawać je "na bieżąco" bez konieczności posiadania wszystkcih danych przed uruchomieniem algorytmu. Są różne powody, dla których tak się robi, ale najczęstrzy jest taki, że przy głębszych architektrurach i bardziej złożonych obiektach (np. obrazach) byłoby fizycznie nie możliwe pomieścić te wszystkie dane w pamięci RAM lub VRAM (RAM na GPU) wraz z parametrami modelu.
#
# Liczbę próbek w algorytmach stochastycznych w sieciach neuronowych określa się jako **minibatch size** lub po prostu **batch size**. Przy czym określenie *batch size* nie odnosi się tutaj do algorytmów batchowych (operujących na całym zbiorze danych), tylko do algorytmów online/minibatch. Po prostu *batch size* jest określeniem krótszym (ale mniej poprawnym) niż *minibatch size*, stąd też powszechnie używa się tego pierwszego. Z tego też powodu czasami niektórzy używają określenia *batch* na *minibatch* - warto mieć to na uwadze przy komunikowaniu się z innymi osobami.
#
# Do zaimplementowania minibatchy wykorzystamy [`torch.utils.data.DataLoader`](https://pytorch.org/docs/stable/data.html#torch.utils.data.DataLoader). ***Zaimplementuj*** funkcję `to_dataloader`, która `X_train` i `y_train` oraz `X_test` i `y_test` umieści w dwóch osobnych instancjach klasy `DataLoader` z wielkością minibatacha równą `batch_size`

# %%
def to_dataloader(
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_test: torch.Tensor,
    y_test: torch.Tensor,
    batch_size: int = 32
) -> Tuple[DataLoader, DataLoader]:
    train_ds = TensorDataset(X_train, y_train)  # Tu jest problem z shuffle 
    train_dl = DataLoader(train_ds, batch_size=batch_size, shuffle=True)

    test_ds = TensorDataset(X_test, y_test)
    test_dl = DataLoader(test_ds, batch_size=batch_size)

    return train_dl, test_dl

# %% [markdown]
# ***Przetestuj*** implementację

# %%
train_loader, test_loader = to_dataloader(
    X_train=X_train,  y_train=y_train,
    X_test=X_test, y_test=y_test,
    batch_size=32
)

for sample in test_loader:
    print(sample)
# Out:
# [tensor([[5.1000, 3.8000, 1.9000, 0.4000],
#         [7.4000, 2.8000, 6.1000, 1.9000],
#         [4.6000, 3.2000, 1.4000, 0.2000],
#         [6.4000, 2.9000, 4.3000, 1.3000],
#         [7.3000, 2.9000, 6.3000, 1.8000],
#         [7.0000, 3.2000, 4.7000, 1.4000],
#         [5.1000, 2.5000, 3.0000, 1.1000],
#         [7.2000, 3.2000, 6.0000, 1.8000],
#         [6.7000, 2.5000, 5.8000, 1.8000],
#         [5.0000, 3.4000, 1.5000, 0.2000],
#         [6.1000, 3.0000, 4.9000, 1.8000],
#         [5.1000, 3.5000, 1.4000, 0.2000],
#         [6.9000, 3.2000, 5.7000, 2.3000],
#         [6.2000, 3.4000, 5.4000, 2.3000],
#         [6.0000, 3.4000, 4.5000, 1.6000],
#         [6.1000, 3.0000, 4.6000, 1.4000],
#         [6.8000, 3.0000, 5.5000, 2.1000],
#         [6.8000, 2.8000, 4.8000, 1.4000],
#         [5.7000, 2.5000, 5.0000, 2.0000],
#         [6.2000, 2.2000, 4.5000, 1.5000],
#         [5.7000, 4.4000, 1.5000, 0.4000],
#         [5.0000, 3.5000, 1.6000, 0.6000],
#         [6.7000, 3.3000, 5.7000, 2.5000],
#         [4.4000, 2.9000, 1.4000, 0.2000],
#         [5.6000, 2.7000, 4.2000, 1.3000],
#         [6.6000, 3.0000, 4.4000, 1.4000],
#         [5.9000, 3.0000, 5.1000, 1.8000],
#         [5.4000, 3.9000, 1.7000, 0.4000],
#         [6.7000, 3.1000, 5.6000, 2.4000],
#         [4.9000, 3.0000, 1.4000, 0.2000],
#         [4.6000, 3.4000, 1.4000, 0.3000],
#         [5.7000, 2.8000, 4.1000, 1.3000]], device='cuda:0'), tensor([0, 2, 0, 1, 2, 1, 1, 2, 2, 0, 2, 0, 2, 2, 1, 1, 2, 1, 2, 1, 0, 0, 2, 0,
#         1, 1, 2, 0, 2, 0, 0, 1], device='cuda:0')]
# [tensor([[6.7000, 3.1000, 4.4000, 1.4000],
#         [6.5000, 3.0000, 5.5000, 1.8000],
#         [6.4000, 2.7000, 5.3000, 1.9000],
#         [4.8000, 3.4000, 1.6000, 0.2000],
#         [5.2000, 3.4000, 1.4000, 0.2000],
#         [5.4000, 3.4000, 1.7000, 0.2000],
#         [4.8000, 3.0000, 1.4000, 0.1000],
#         [6.5000, 3.0000, 5.2000, 2.0000],
#         [6.5000, 2.8000, 4.6000, 1.5000],
#         [7.1000, 3.0000, 5.9000, 2.1000],
#         [4.9000, 3.1000, 1.5000, 0.2000],
#         [5.4000, 3.9000, 1.3000, 0.4000],
#         [6.5000, 3.0000, 5.8000, 2.2000],
#         [4.9000, 2.5000, 4.5000, 1.7000],
#         [6.1000, 2.8000, 4.7000, 1.2000],
#         [4.9000, 3.1000, 1.5000, 0.1000],
#         [5.0000, 3.0000, 1.6000, 0.2000],
#         [4.9000, 2.4000, 3.3000, 1.0000],
#         [6.9000, 3.1000, 5.1000, 2.3000],
#         [5.5000, 2.3000, 4.0000, 1.3000],
#         [5.6000, 3.0000, 4.5000, 1.5000],
#         [6.3000, 3.3000, 4.7000, 1.6000],
#         [5.6000, 2.8000, 4.9000, 2.0000],
#         [5.4000, 3.0000, 4.5000, 1.5000],
#         [5.7000, 3.8000, 1.7000, 0.3000],
#         [4.9000, 3.6000, 1.4000, 0.1000],
#         [6.0000, 2.2000, 4.0000, 1.0000],
#         [6.1000, 2.8000, 4.0000, 1.3000]], device='cuda:0'), tensor([1, 2, 2, 0, 0, 0, 0, 2, 1, 2, 0, 0, 2, 2, 1, 0, 0, 1, 2, 1, 1, 1, 2, 1,
#         0, 0, 1, 1], device='cuda:0')]

# %% [markdown]
# ## Ewaluacja modelu - metryki
#
# ***Zaimplementuj*** funkcję `validate`, które dla danego modelu, funkcji straty i loadera zwróci średnią wartość funkcji straty oraz dokładność (ang. *accuracy*) dla danych z `dataloader`.

# %%
def count_correct(
    y_pred: torch.Tensor, y_true: torch.Tensor
) -> torch.Tensor:
    preds = torch.argmax(y_pred, dim=1)
    return (preds == y_true).float().sum()

def validate(
    model: nn.Module,
    loss_fn: torch.nn.CrossEntropyLoss,
    dataloader: DataLoader
) -> Tuple[torch.Tensor, torch.Tensor]:
    loss = 0
    correct = 0
    all = 0
    for X_batch, y_batch in dataloader:
        y_pred = model.forward(X_batch)
        all += len(y_pred)
        loss += len(y_pred) * loss_fn(y_pred, y_batch)
        correct += count_correct(y_pred, y_batch)
    return loss / all, correct / all

# %% [markdown]
# ***Przetestuj*** swoją implementację

# %%
loss_fn = torch.nn.CrossEntropyLoss()
val_train, acc_train = validate(model, loss_fn, test_loader)
print(val_train, acc_train)
# Out:
# tensor(1.1736, device='cuda:0', grad_fn=<DivBackward0>) tensor(0.3333, device='cuda:0')

# %% [markdown]
# ## Uczenie
#
# Przed uzupełnieniem poniżej implementacji została nam jeszcze jedna istotna kwestia do poruszenia. Otóż dot tej pory aktualizację parametrów dokonywaliśmy wg prostej formuły - mnożyliśmy gradienty przez współczynnik uczenia (ang. *learning rate*) i odejmowalismy od parametrów. Jednakże do uczenia sieci neuronowych sotsujemy często optymalizatory (ang. *optimiser*), które mogą implementować różne podejścia do uakualiniania parameterów modelu. Wykorzystamy tutaj algorytm **Adam** (ang. *adaptive moment estimation*), który dostosowuje współczynnik uczenia do poszczególnych parametrów i jest często optimizatorem pierwszego wyboru.
#
# ***Uzupełnij i przetestuj*** poniższą implementację uczenia modelu. Porównaj jej skuteczność z tą, którą zaimplementowałeś(aś) na laboratorium 2.

# %%
normal_train_acc = []
normal_train_loss = []

normal_test_acc = []
normal_test_loss = []


def fit(
    model: nn.Module, optimiser: optim.Optimizer,
    loss_fn: torch.nn.CrossEntropyLoss, train_dl: DataLoader,
    val_dl: DataLoader, epochs: int,
    print_metrics: str = True
):
    for epoch in range(epochs):
        for X_batch, y_batch in train_dl:
            y_pred = model(X_batch) # Uzyskanie pseudoprawdopodobieństw dla próbek z minibatcha
            loss = loss_fn(y_pred, y_batch) # Policzenie funkcji straty

            loss.backward() # Wsteczna propagacja z wyniku funkcji straty - policzenie gradientów i zapisanie ich w tensorach (parametrach)
            optimiser.step() # Aktualizacja parametrów modelu przez optymalizator na podstawie gradientów zapisanych w tensorach (parametrach) oraz lr
            optimiser.zero_grad() # Wyzerowanie gradientów w modelu, alternatywnie można wywołać percepron.zero_grad()

        if print_metrics:
            model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm
            with torch.no_grad():  # Wstrzymujemy przeliczanie i śledzenie gradientów dla tensorów - w procesie ewaluacji modelu nie chcemy zmian w gradientach
                train_loss, train_acc = validate(model, loss_fn, train_dl)
                val_loss, val_acc = validate(model, loss_fn, val_dl)
                print(
                    f"Epoch {epoch}: "
                    f"train loss = {train_loss:.3f} (acc: {train_acc:.3f}), "
                    f"validation loss = {val_loss:.3f} (acc: {val_acc:.3f})"
                )
                normal_train_acc.append(train_acc.cpu().numpy())
                normal_train_loss.append(train_loss.cpu().numpy())
                normal_test_acc.append(val_acc.cpu().numpy())
                normal_test_loss.append(val_loss.cpu().numpy())



    model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm

train_dl, test_dl = to_dataloader(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    batch_size=32
)

print(X_train.shape)
print(y_train.shape)

perceptron = Perceptron(4,3).cuda()
optimiser = optim.Adam(perceptron.parameters(), lr=0.001)
loss_fn = torch.nn.CrossEntropyLoss()
fit(
    model=perceptron, optimiser=optimiser, loss_fn=loss_fn,
    train_dl=train_dl, val_dl=test_dl, epochs=50
)
# Out:
# torch.Size([90, 4])
# torch.Size([90])
# Epoch 0: train loss = 1.760 (acc: 0.411), validation loss = 1.779 (acc: 0.417)
# Epoch 1: train loss = 1.732 (acc: 0.422), validation loss = 1.751 (acc: 0.417)
# Epoch 2: train loss = 1.705 (acc: 0.489), validation loss = 1.724 (acc: 0.483)
# Epoch 3: train loss = 1.679 (acc: 0.489), validation loss = 1.697 (acc: 0.483)
# Epoch 4: train loss = 1.652 (acc: 0.489), validation loss = 1.670 (acc: 0.517)
# Epoch 5: train loss = 1.627 (acc: 0.522), validation loss = 1.644 (acc: 0.567)
# Epoch 6: train loss = 1.602 (acc: 0.533), validation loss = 1.619 (acc: 0.567)
# Epoch 7: train loss = 1.577 (acc: 0.544), validation loss = 1.594 (acc: 0.567)
# Epoch 8: train loss = 1.553 (acc: 0.578), validation loss = 1.569 (acc: 0.583)
# Epoch 9: train loss = 1.530 (acc: 0.600), validation loss = 1.545 (acc: 0.600)
# Epoch 10: train loss = 1.506 (acc: 0.611), validation loss = 1.522 (acc: 0.617)
# Epoch 11: train loss = 1.484 (acc: 0.633), validation loss = 1.499 (acc: 0.617)
# Epoch 12: train loss = 1.462 (acc: 0.633), validation loss = 1.476 (acc: 0.650)
# Epoch 13: train loss = 1.440 (acc: 0.633), validation loss = 1.453 (acc: 0.650)
# Epoch 14: train loss = 1.419 (acc: 0.633), validation loss = 1.432 (acc: 0.650)
# Epoch 15: train loss = 1.398 (acc: 0.633), validation loss = 1.411 (acc: 0.650)
# Epoch 16: train loss = 1.377 (acc: 0.633), validation loss = 1.389 (acc: 0.650)
# Epoch 17: train loss = 1.357 (acc: 0.633), validation loss = 1.369 (acc: 0.650)
# Epoch 18: train loss = 1.338 (acc: 0.644), validation loss = 1.349 (acc: 0.650)
# Epoch 19: train loss = 1.319 (acc: 0.644), validation loss = 1.329 (acc: 0.650)
# Epoch 20: train loss = 1.301 (acc: 0.644), validation loss = 1.311 (acc: 0.650)
# Epoch 21: train loss = 1.284 (acc: 0.644), validation loss = 1.293 (acc: 0.650)
# Epoch 22: train loss = 1.267 (acc: 0.656), validation loss = 1.276 (acc: 0.650)
# Epoch 23: train loss = 1.251 (acc: 0.656), validation loss = 1.259 (acc: 0.650)
# Epoch 24: train loss = 1.236 (acc: 0.656), validation loss = 1.244 (acc: 0.650)
# Epoch 25: train loss = 1.221 (acc: 0.656), validation loss = 1.228 (acc: 0.650)
# Epoch 26: train loss = 1.206 (acc: 0.656), validation loss = 1.214 (acc: 0.650)
# Epoch 27: train loss = 1.192 (acc: 0.656), validation loss = 1.199 (acc: 0.650)
# Epoch 28: train loss = 1.179 (acc: 0.656), validation loss = 1.186 (acc: 0.667)
# Epoch 29: train loss = 1.167 (acc: 0.656), validation loss = 1.173 (acc: 0.667)
# Epoch 30: train loss = 1.155 (acc: 0.656), validation loss = 1.161 (acc: 0.667)
# Epoch 31: train loss = 1.144 (acc: 0.633), validation loss = 1.149 (acc: 0.667)
# Epoch 32: train loss = 1.133 (acc: 0.622), validation loss = 1.138 (acc: 0.633)
# Epoch 33: train loss = 1.122 (acc: 0.589), validation loss = 1.127 (acc: 0.600)
# Epoch 34: train loss = 1.113 (acc: 0.567), validation loss = 1.117 (acc: 0.567)
# Epoch 35: train loss = 1.103 (acc: 0.489), validation loss = 1.108 (acc: 0.500)
# Epoch 36: train loss = 1.095 (acc: 0.456), validation loss = 1.099 (acc: 0.450)
# Epoch 37: train loss = 1.086 (acc: 0.411), validation loss = 1.090 (acc: 0.433)
# Epoch 38: train loss = 1.079 (acc: 0.378), validation loss = 1.082 (acc: 0.433)
# Epoch 39: train loss = 1.071 (acc: 0.367), validation loss = 1.075 (acc: 0.383)
# Epoch 40: train loss = 1.064 (acc: 0.356), validation loss = 1.068 (acc: 0.350)
# Epoch 41: train loss = 1.058 (acc: 0.344), validation loss = 1.061 (acc: 0.350)
# Epoch 42: train loss = 1.051 (acc: 0.344), validation loss = 1.055 (acc: 0.350)
# Epoch 43: train loss = 1.046 (acc: 0.344), validation loss = 1.049 (acc: 0.350)
# Epoch 44: train loss = 1.040 (acc: 0.333), validation loss = 1.043 (acc: 0.350)
# Epoch 45: train loss = 1.035 (acc: 0.333), validation loss = 1.038 (acc: 0.350)
# Epoch 46: train loss = 1.030 (acc: 0.333), validation loss = 1.032 (acc: 0.333)
# Epoch 47: train loss = 1.025 (acc: 0.333), validation loss = 1.028 (acc: 0.333)
# Epoch 48: train loss = 1.020 (acc: 0.333), validation loss = 1.023 (acc: 0.333)
# Epoch 49: train loss = 1.016 (acc: 0.333), validation loss = 1.018 (acc: 0.333)

# %%
import matplotlib.pyplot as plt

plt.plot(range(50),normal_test_loss)
plt.plot(range(50),normal_train_loss)
plt.xlabel("Liczba Epoch")
plt.ylabel("Funkcja Loss")
plt.legend(["Loss zbioru testowego", "Loss zbioru traningowego"])

plt.show()


plt.plot(range(50),normal_test_acc)
plt.plot(range(50),normal_train_acc)
plt.legend(["Accuracy zbioru testowego", "Accuracy zbioru traningowego"])
plt.xlabel("Liczba Epoch")
plt.ylabel("Funkcja Accuracy")
plt.ylim([0,1.05])
plt.show()

# %%
def new_to_dataloader(
    X_train: torch.Tensor,
    y_train: torch.Tensor,
    X_test: torch.Tensor,
    y_test: torch.Tensor,
    batch_size: int = 32
) -> Tuple[DataLoader, DataLoader]:
    train_ds = TensorDataset(X_train, y_train)  # Tu jest problem z shuffle 
    train_dl = DataLoader(train_ds, batch_size=batch_size)

    test_ds = TensorDataset(X_test, y_test)
    test_set_size = int(len(test_ds) * 0.5)
    valid_set_size = len(test_ds) - test_set_size
    generator1 = torch.Generator().manual_seed(1)
    val_ds, test_ds = torch.utils.data.random_split(test_ds, [valid_set_size, test_set_size], generator=generator1)

    val_dl = DataLoader(val_ds, batch_size=batch_size)
    test_dl = DataLoader(test_ds, batch_size=batch_size)

    return train_dl, val_dl, test_dl

# %%
boosted_train_acc = []
boosted_val_acc = []
boosted_test_acc = []
boosted_train_loss = []
boosted_val_loss = []
boosted_test_loss = []

def fit(
    model: nn.Module, optimiser: optim.Optimizer,
    loss_fn: torch.nn.CrossEntropyLoss, train_dl: DataLoader,
    val_dl: DataLoader,test_dl: DataLoader, epochs: int,
    print_metrics: str = True
):
    for epoch in range(epochs):
        for X_batch, y_batch in train_dl:
            y_pred = model(X_batch) # Uzyskanie pseudoprawdopodobieństw dla próbek z minibatcha
            loss = loss_fn(y_pred, y_batch) # Policzenie funkcji straty

            loss.backward() # Wsteczna propagacja z wyniku funkcji straty - policzenie gradientów i zapisanie ich w tensorach (parametrach)
            optimiser.step() # Aktualizacja parametrów modelu przez optymalizator na podstawie gradientów zapisanych w tensorach (parametrach) oraz lr
            optimiser.zero_grad() # Wyzerowanie gradientów w modelu, alternatywnie można wywołać percepron.zero_grad()

        if print_metrics:
            model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm
            with torch.no_grad():  # Wstrzymujemy przeliczanie i śledzenie gradientów dla tensorów - w procesie ewaluacji modelu nie chcemy zmian w gradientach
                train_loss, train_acc = validate(model, loss_fn, train_dl)
                val_loss, val_acc = validate(model, loss_fn, val_dl)
                test_loss, test_acc = validate(model, loss_fn, test_dl)

                print(
                    f"Epoch {epoch}: "
                    f"train loss = {train_loss:.3f} (acc: {train_acc:.3f}), "
                    f"validation loss = {val_loss:.3f} (acc: {val_acc:.3f})"
                    f"test loss = {test_loss:.3f} (acc: {test_acc:.3f})"
                )
                boosted_train_acc.append(train_acc.cpu().numpy())
                boosted_train_loss.append(train_loss.cpu().numpy())
                boosted_val_acc.append(val_acc.cpu().numpy())
                boosted_val_loss.append(val_loss.cpu().numpy())
                boosted_test_acc.append(test_acc.cpu().numpy())
                boosted_test_loss.append(test_loss.cpu().numpy())



    model.eval() # Przełączenie na tryb ewaluacji modelu - istotne dla takich warstw jak Dropuot czy BatchNorm

train_dl, val_dl, test_dl = new_to_dataloader(
    X_train=X_train,
    y_train=y_train,
    X_test=X_test,
    y_test=y_test,
    batch_size=32
)

perceptron = Perceptron(4,3).cuda()
optimiser = optim.Adam(perceptron.parameters(), lr=0.1)
loss_fn = torch.nn.CrossEntropyLoss()
fit(
    model=perceptron, optimiser=optimiser, loss_fn=loss_fn,
    train_dl=train_dl, val_dl=val_dl, test_dl=test_dl, epochs=1000
)
# Out:
# Epoch 0: train loss = 1.686 (acc: 0.667), validation loss = 1.900 (acc: 0.600)test loss = 1.411 (acc: 0.733)
# Epoch 1: train loss = 0.811 (acc: 0.667), validation loss = 0.830 (acc: 0.667)test loss = 0.804 (acc: 0.667)
# Epoch 2: train loss = 0.844 (acc: 0.667), validation loss = 0.842 (acc: 0.667)test loss = 0.885 (acc: 0.667)
# Epoch 3: train loss = 0.640 (acc: 0.667), validation loss = 0.698 (acc: 0.600)test loss = 0.564 (acc: 0.733)
# Epoch 4: train loss = 0.596 (acc: 0.667), validation loss = 0.654 (acc: 0.600)test loss = 0.517 (acc: 0.733)
# Epoch 5: train loss = 0.509 (acc: 0.667), validation loss = 0.524 (acc: 0.667)test loss = 0.501 (acc: 0.667)
# Epoch 6: train loss = 0.464 (acc: 0.667), validation loss = 0.478 (acc: 0.667)test loss = 0.454 (acc: 0.667)
# Epoch 7: train loss = 0.457 (acc: 0.700), validation loss = 0.494 (acc: 0.633)test loss = 0.407 (acc: 0.733)
# Epoch 8: train loss = 0.410 (acc: 0.856), validation loss = 0.436 (acc: 0.867)test loss = 0.375 (acc: 0.900)
# Epoch 9: train loss = 0.398 (acc: 0.711), validation loss = 0.409 (acc: 0.700)test loss = 0.388 (acc: 0.733)
# Epoch 10: train loss = 0.365 (acc: 0.933), validation loss = 0.379 (acc: 0.933)test loss = 0.346 (acc: 0.900)
# Epoch 11: train loss = 0.372 (acc: 0.856), validation loss = 0.394 (acc: 0.867)test loss = 0.336 (acc: 0.900)
# Epoch 12: train loss = 0.340 (acc: 0.944), validation loss = 0.351 (acc: 0.967)test loss = 0.318 (acc: 1.000)
# Epoch 13: train loss = 0.333 (acc: 0.933), validation loss = 0.340 (acc: 0.933)test loss = 0.319 (acc: 0.900)
# Epoch 14: train loss = 0.321 (acc: 0.933), validation loss = 0.330 (acc: 1.000)test loss = 0.297 (acc: 1.000)
# Epoch 15: train loss = 0.314 (acc: 0.933), validation loss = 0.322 (acc: 1.000)test loss = 0.289 (acc: 0.967)
# Epoch 16: train loss = 0.300 (acc: 0.956), validation loss = 0.303 (acc: 0.967)test loss = 0.283 (acc: 0.967)
# Epoch 17: train loss = 0.292 (acc: 0.933), validation loss = 0.293 (acc: 0.967)test loss = 0.274 (acc: 1.000)
# Epoch 18: train loss = 0.287 (acc: 0.944), validation loss = 0.290 (acc: 1.000)test loss = 0.265 (acc: 1.000)
# Epoch 19: train loss = 0.277 (acc: 0.956), validation loss = 0.277 (acc: 1.000)test loss = 0.258 (acc: 1.000)
# Epoch 20: train loss = 0.270 (acc: 0.933), validation loss = 0.267 (acc: 0.967)test loss = 0.253 (acc: 1.000)
# Epoch 21: train loss = 0.264 (acc: 0.956), validation loss = 0.261 (acc: 1.000)test loss = 0.244 (acc: 1.000)
# Epoch 22: train loss = 0.258 (acc: 0.956), validation loss = 0.254 (acc: 1.000)test loss = 0.238 (acc: 1.000)
# Epoch 23: train loss = 0.251 (acc: 0.956), validation loss = 0.245 (acc: 1.000)test loss = 0.233 (acc: 1.000)
# Epoch 24: train loss = 0.246 (acc: 0.956), validation loss = 0.239 (acc: 1.000)test loss = 0.227 (acc: 1.000)
# Epoch 25: train loss = 0.241 (acc: 0.956), validation loss = 0.234 (acc: 1.000)test loss = 0.222 (acc: 1.000)
# Epoch 26: train loss = 0.236 (acc: 0.956), validation loss = 0.227 (acc: 1.000)test loss = 0.217 (acc: 1.000)
# Epoch 27: train loss = 0.231 (acc: 0.956), validation loss = 0.221 (acc: 1.000)test loss = 0.212 (acc: 1.000)
# Epoch 28: train loss = 0.227 (acc: 0.956), validation loss = 0.216 (acc: 1.000)test loss = 0.207 (acc: 1.000)
# Epoch 29: train loss = 0.222 (acc: 0.956), validation loss = 0.211 (acc: 1.000)test loss = 0.203 (acc: 1.000)
# Epoch 30: train loss = 0.218 (acc: 0.956), validation loss = 0.205 (acc: 1.000)test loss = 0.199 (acc: 1.000)
# Epoch 31: train loss = 0.214 (acc: 0.956), validation loss = 0.201 (acc: 1.000)test loss = 0.195 (acc: 1.000)
# Epoch 32: train loss = 0.211 (acc: 0.956), validation loss = 0.196 (acc: 1.000)test loss = 0.190 (acc: 1.000)
# Epoch 33: train loss = 0.207 (acc: 0.956), validation loss = 0.192 (acc: 1.000)test loss = 0.187 (acc: 1.000)
# Epoch 34: train loss = 0.203 (acc: 0.956), validation loss = 0.188 (acc: 1.000)test loss = 0.183 (acc: 1.000)
# Epoch 35: train loss = 0.200 (acc: 0.956), validation loss = 0.184 (acc: 1.000)test loss = 0.179 (acc: 1.000)
# Epoch 36: train loss = 0.197 (acc: 0.956), validation loss = 0.180 (acc: 1.000)test loss = 0.176 (acc: 1.000)
# Epoch 37: train loss = 0.194 (acc: 0.956), validation loss = 0.176 (acc: 1.000)test loss = 0.173 (acc: 1.000)
# Epoch 38: train loss = 0.191 (acc: 0.956), validation loss = 0.173 (acc: 1.000)test loss = 0.170 (acc: 1.000)
# Epoch 39: train loss = 0.188 (acc: 0.956), validation loss = 0.169 (acc: 1.000)test loss = 0.166 (acc: 1.000)
# Epoch 40: train loss = 0.185 (acc: 0.956), validation loss = 0.166 (acc: 1.000)test loss = 0.164 (acc: 1.000)
# Epoch 41: train loss = 0.183 (acc: 0.956), validation loss = 0.163 (acc: 1.000)test loss = 0.161 (acc: 1.000)
# Epoch 42: train loss = 0.180 (acc: 0.956), validation loss = 0.160 (acc: 1.000)test loss = 0.158 (acc: 1.000)
# Epoch 43: train loss = 0.178 (acc: 0.956), validation loss = 0.157 (acc: 1.000)test loss = 0.155 (acc: 1.000)
# Epoch 44: train loss = 0.175 (acc: 0.956), validation loss = 0.154 (acc: 1.000)test loss = 0.153 (acc: 1.000)
# Epoch 45: train loss = 0.173 (acc: 0.956), validation loss = 0.151 (acc: 1.000)test loss = 0.150 (acc: 1.000)
# Epoch 46: train loss = 0.171 (acc: 0.956), validation loss = 0.149 (acc: 1.000)test loss = 0.148 (acc: 1.000)
# Epoch 47: train loss = 0.169 (acc: 0.956), validation loss = 0.146 (acc: 1.000)test loss = 0.145 (acc: 1.000)
# Epoch 48: train loss = 0.167 (acc: 0.956), validation loss = 0.144 (acc: 1.000)test loss = 0.143 (acc: 1.000)
# Epoch 49: train loss = 0.165 (acc: 0.956), validation loss = 0.141 (acc: 1.000)test loss = 0.141 (acc: 1.000)
# Epoch 50: train loss = 0.163 (acc: 0.956), validation loss = 0.139 (acc: 1.000)test loss = 0.139 (acc: 1.000)
# Epoch 51: train loss = 0.161 (acc: 0.956), validation loss = 0.137 (acc: 1.000)test loss = 0.137 (acc: 1.000)
# Epoch 52: train loss = 0.159 (acc: 0.956), validation loss = 0.135 (acc: 1.000)test loss = 0.134 (acc: 1.000)
# Epoch 53: train loss = 0.158 (acc: 0.956), validation loss = 0.133 (acc: 1.000)test loss = 0.133 (acc: 1.000)
# Epoch 54: train loss = 0.156 (acc: 0.956), validation loss = 0.131 (acc: 1.000)test loss = 0.131 (acc: 1.000)
# Epoch 55: train loss = 0.154 (acc: 0.956), validation loss = 0.129 (acc: 1.000)test loss = 0.129 (acc: 1.000)
# Epoch 56: train loss = 0.153 (acc: 0.956), validation loss = 0.127 (acc: 1.000)test loss = 0.127 (acc: 1.000)
# Epoch 57: train loss = 0.151 (acc: 0.967), validation loss = 0.125 (acc: 1.000)test loss = 0.125 (acc: 1.000)
# Epoch 58: train loss = 0.150 (acc: 0.967), validation loss = 0.124 (acc: 1.000)test loss = 0.123 (acc: 1.000)
# Epoch 59: train loss = 0.148 (acc: 0.967), validation loss = 0.122 (acc: 1.000)test loss = 0.122 (acc: 1.000)
# Epoch 60: train loss = 0.147 (acc: 0.967), validation loss = 0.120 (acc: 1.000)test loss = 0.120 (acc: 1.000)
# Epoch 61: train loss = 0.146 (acc: 0.967), validation loss = 0.119 (acc: 1.000)test loss = 0.119 (acc: 1.000)
# Epoch 62: train loss = 0.144 (acc: 0.967), validation loss = 0.117 (acc: 1.000)test loss = 0.117 (acc: 1.000)
# Epoch 63: train loss = 0.143 (acc: 0.967), validation loss = 0.116 (acc: 1.000)test loss = 0.115 (acc: 1.000)
# Epoch 64: train loss = 0.142 (acc: 0.967), validation loss = 0.114 (acc: 1.000)test loss = 0.114 (acc: 1.000)
# Epoch 65: train loss = 0.141 (acc: 0.967), validation loss = 0.113 (acc: 1.000)test loss = 0.113 (acc: 1.000)
# Epoch 66: train loss = 0.139 (acc: 0.967), validation loss = 0.111 (acc: 1.000)test loss = 0.111 (acc: 1.000)
# Epoch 67: train loss = 0.138 (acc: 0.967), validation loss = 0.110 (acc: 1.000)test loss = 0.110 (acc: 1.000)
# Epoch 68: train loss = 0.137 (acc: 0.967), validation loss = 0.109 (acc: 1.000)test loss = 0.108 (acc: 1.000)
# Epoch 69: train loss = 0.136 (acc: 0.967), validation loss = 0.107 (acc: 1.000)test loss = 0.107 (acc: 1.000)
# Epoch 70: train loss = 0.135 (acc: 0.967), validation loss = 0.106 (acc: 1.000)test loss = 0.106 (acc: 1.000)
# Epoch 71: train loss = 0.134 (acc: 0.967), validation loss = 0.105 (acc: 1.000)test loss = 0.105 (acc: 1.000)
# Epoch 72: train loss = 0.133 (acc: 0.967), validation loss = 0.104 (acc: 1.000)test loss = 0.103 (acc: 1.000)
# Epoch 73: train loss = 0.132 (acc: 0.967), validation loss = 0.103 (acc: 1.000)test loss = 0.102 (acc: 1.000)
# Epoch 74: train loss = 0.131 (acc: 0.967), validation loss = 0.101 (acc: 1.000)test loss = 0.101 (acc: 1.000)
# Epoch 75: train loss = 0.130 (acc: 0.967), validation loss = 0.100 (acc: 1.000)test loss = 0.100 (acc: 1.000)
# Epoch 76: train loss = 0.129 (acc: 0.967), validation loss = 0.099 (acc: 1.000)test loss = 0.099 (acc: 1.000)
# Epoch 77: train loss = 0.128 (acc: 0.967), validation loss = 0.098 (acc: 1.000)test loss = 0.098 (acc: 1.000)
# Epoch 78: train loss = 0.128 (acc: 0.967), validation loss = 0.097 (acc: 1.000)test loss = 0.097 (acc: 1.000)
# Epoch 79: train loss = 0.127 (acc: 0.967), validation loss = 0.096 (acc: 1.000)test loss = 0.096 (acc: 1.000)
# Epoch 80: train loss = 0.126 (acc: 0.967), validation loss = 0.095 (acc: 1.000)test loss = 0.095 (acc: 1.000)
# Epoch 81: train loss = 0.125 (acc: 0.967), validation loss = 0.094 (acc: 1.000)test loss = 0.093 (acc: 1.000)
# Epoch 82: train loss = 0.124 (acc: 0.967), validation loss = 0.094 (acc: 1.000)test loss = 0.093 (acc: 1.000)
# Epoch 83: train loss = 0.123 (acc: 0.967), validation loss = 0.093 (acc: 1.000)test loss = 0.092 (acc: 1.000)
# Epoch 84: train loss = 0.123 (acc: 0.967), validation loss = 0.092 (acc: 1.000)test loss = 0.091 (acc: 1.000)
# Epoch 85: train loss = 0.122 (acc: 0.967), validation loss = 0.091 (acc: 1.000)test loss = 0.090 (acc: 1.000)
# Epoch 86: train loss = 0.121 (acc: 0.967), validation loss = 0.090 (acc: 1.000)test loss = 0.089 (acc: 1.000)
# Epoch 87: train loss = 0.121 (acc: 0.967), validation loss = 0.089 (acc: 1.000)test loss = 0.088 (acc: 1.000)
# Epoch 88: train loss = 0.120 (acc: 0.967), validation loss = 0.089 (acc: 1.000)test loss = 0.087 (acc: 1.000)
# Epoch 89: train loss = 0.119 (acc: 0.967), validation loss = 0.088 (acc: 1.000)test loss = 0.086 (acc: 1.000)
# Epoch 90: train loss = 0.119 (acc: 0.967), validation loss = 0.087 (acc: 1.000)test loss = 0.085 (acc: 1.000)
# Epoch 91: train loss = 0.118 (acc: 0.967), validation loss = 0.086 (acc: 1.000)test loss = 0.084 (acc: 1.000)
# Epoch 92: train loss = 0.117 (acc: 0.967), validation loss = 0.086 (acc: 1.000)test loss = 0.084 (acc: 1.000)
# Epoch 93: train loss = 0.117 (acc: 0.967), validation loss = 0.085 (acc: 1.000)test loss = 0.083 (acc: 1.000)
# Epoch 94: train loss = 0.116 (acc: 0.967), validation loss = 0.084 (acc: 1.000)test loss = 0.082 (acc: 1.000)
# Epoch 95: train loss = 0.115 (acc: 0.967), validation loss = 0.084 (acc: 1.000)test loss = 0.081 (acc: 1.000)
# Epoch 96: train loss = 0.115 (acc: 0.967), validation loss = 0.083 (acc: 1.000)test loss = 0.081 (acc: 1.000)
# Epoch 97: train loss = 0.114 (acc: 0.967), validation loss = 0.082 (acc: 1.000)test loss = 0.080 (acc: 1.000)
# Epoch 98: train loss = 0.114 (acc: 0.967), validation loss = 0.082 (acc: 1.000)test loss = 0.079 (acc: 1.000)
# Epoch 99: train loss = 0.113 (acc: 0.967), validation loss = 0.081 (acc: 1.000)test loss = 0.078 (acc: 1.000)
# Epoch 100: train loss = 0.113 (acc: 0.967), validation loss = 0.080 (acc: 1.000)test loss = 0.078 (acc: 1.000)
# Epoch 101: train loss = 0.112 (acc: 0.967), validation loss = 0.080 (acc: 1.000)test loss = 0.077 (acc: 1.000)
# Epoch 102: train loss = 0.112 (acc: 0.967), validation loss = 0.079 (acc: 1.000)test loss = 0.076 (acc: 1.000)
# Epoch 103: train loss = 0.111 (acc: 0.967), validation loss = 0.079 (acc: 1.000)test loss = 0.076 (acc: 1.000)
# Epoch 104: train loss = 0.110 (acc: 0.967), validation loss = 0.078 (acc: 1.000)test loss = 0.075 (acc: 1.000)
# Epoch 105: train loss = 0.110 (acc: 0.967), validation loss = 0.078 (acc: 1.000)test loss = 0.074 (acc: 1.000)
# Epoch 106: train loss = 0.110 (acc: 0.967), validation loss = 0.077 (acc: 1.000)test loss = 0.074 (acc: 1.000)
# Epoch 107: train loss = 0.109 (acc: 0.967), validation loss = 0.077 (acc: 1.000)test loss = 0.073 (acc: 1.000)
# Epoch 108: train loss = 0.109 (acc: 0.967), validation loss = 0.076 (acc: 1.000)test loss = 0.072 (acc: 1.000)
# Epoch 109: train loss = 0.108 (acc: 0.967), validation loss = 0.075 (acc: 1.000)test loss = 0.072 (acc: 1.000)
# Epoch 110: train loss = 0.108 (acc: 0.956), validation loss = 0.075 (acc: 1.000)test loss = 0.071 (acc: 1.000)
# Epoch 111: train loss = 0.107 (acc: 0.956), validation loss = 0.075 (acc: 1.000)test loss = 0.071 (acc: 1.000)
# Epoch 112: train loss = 0.107 (acc: 0.956), validation loss = 0.074 (acc: 1.000)test loss = 0.070 (acc: 1.000)
# Epoch 113: train loss = 0.106 (acc: 0.956), validation loss = 0.074 (acc: 1.000)test loss = 0.069 (acc: 1.000)
# Epoch 114: train loss = 0.106 (acc: 0.956), validation loss = 0.073 (acc: 1.000)test loss = 0.069 (acc: 1.000)
# Epoch 115: train loss = 0.105 (acc: 0.956), validation loss = 0.073 (acc: 1.000)test loss = 0.068 (acc: 1.000)
# Epoch 116: train loss = 0.105 (acc: 0.956), validation loss = 0.072 (acc: 1.000)test loss = 0.068 (acc: 1.000)
# Epoch 117: train loss = 0.105 (acc: 0.956), validation loss = 0.072 (acc: 1.000)test loss = 0.067 (acc: 1.000)
# Epoch 118: train loss = 0.104 (acc: 0.956), validation loss = 0.071 (acc: 1.000)test loss = 0.067 (acc: 1.000)
# Epoch 119: train loss = 0.104 (acc: 0.956), validation loss = 0.071 (acc: 1.000)test loss = 0.066 (acc: 1.000)
# Epoch 120: train loss = 0.104 (acc: 0.956), validation loss = 0.071 (acc: 1.000)test loss = 0.066 (acc: 1.000)
# Epoch 121: train loss = 0.103 (acc: 0.956), validation loss = 0.070 (acc: 1.000)test loss = 0.065 (acc: 1.000)
# Epoch 122: train loss = 0.103 (acc: 0.956), validation loss = 0.070 (acc: 1.000)test loss = 0.065 (acc: 1.000)
# Epoch 123: train loss = 0.102 (acc: 0.956), validation loss = 0.069 (acc: 1.000)test loss = 0.064 (acc: 1.000)
# Epoch 124: train loss = 0.102 (acc: 0.956), validation loss = 0.069 (acc: 1.000)test loss = 0.064 (acc: 1.000)
# Epoch 125: train loss = 0.102 (acc: 0.956), validation loss = 0.069 (acc: 1.000)test loss = 0.063 (acc: 1.000)
# Epoch 126: train loss = 0.101 (acc: 0.956), validation loss = 0.068 (acc: 1.000)test loss = 0.063 (acc: 1.000)
# Epoch 127: train loss = 0.101 (acc: 0.956), validation loss = 0.068 (acc: 1.000)test loss = 0.062 (acc: 1.000)
# Epoch 128: train loss = 0.101 (acc: 0.956), validation loss = 0.067 (acc: 1.000)test loss = 0.062 (acc: 1.000)
# Epoch 129: train loss = 0.100 (acc: 0.956), validation loss = 0.067 (acc: 1.000)test loss = 0.061 (acc: 1.000)
# Epoch 130: train loss = 0.100 (acc: 0.956), validation loss = 0.067 (acc: 1.000)test loss = 0.061 (acc: 1.000)
# Epoch 131: train loss = 0.100 (acc: 0.956), validation loss = 0.066 (acc: 1.000)test loss = 0.060 (acc: 1.000)
# Epoch 132: train loss = 0.099 (acc: 0.956), validation loss = 0.066 (acc: 1.000)test loss = 0.060 (acc: 1.000)
# Epoch 133: train loss = 0.099 (acc: 0.956), validation loss = 0.066 (acc: 1.000)test loss = 0.059 (acc: 1.000)
# Epoch 134: train loss = 0.099 (acc: 0.956), validation loss = 0.065 (acc: 1.000)test loss = 0.059 (acc: 1.000)
# Epoch 135: train loss = 0.098 (acc: 0.956), validation loss = 0.065 (acc: 1.000)test loss = 0.059 (acc: 1.000)
# Epoch 136: train loss = 0.098 (acc: 0.956), validation loss = 0.065 (acc: 1.000)test loss = 0.058 (acc: 1.000)
# Epoch 137: train loss = 0.098 (acc: 0.956), validation loss = 0.064 (acc: 1.000)test loss = 0.058 (acc: 1.000)
# Epoch 138: train loss = 0.098 (acc: 0.956), validation loss = 0.064 (acc: 1.000)test loss = 0.057 (acc: 1.000)
# Epoch 139: train loss = 0.097 (acc: 0.956), validation loss = 0.064 (acc: 1.000)test loss = 0.057 (acc: 1.000)
# Epoch 140: train loss = 0.097 (acc: 0.956), validation loss = 0.064 (acc: 1.000)test loss = 0.057 (acc: 1.000)
# Epoch 141: train loss = 0.097 (acc: 0.956), validation loss = 0.063 (acc: 1.000)test loss = 0.056 (acc: 1.000)
# Epoch 142: train loss = 0.096 (acc: 0.956), validation loss = 0.063 (acc: 1.000)test loss = 0.056 (acc: 1.000)
# Epoch 143: train loss = 0.096 (acc: 0.956), validation loss = 0.063 (acc: 1.000)test loss = 0.055 (acc: 1.000)
# Epoch 144: train loss = 0.096 (acc: 0.956), validation loss = 0.062 (acc: 1.000)test loss = 0.055 (acc: 1.000)
# Epoch 145: train loss = 0.096 (acc: 0.956), validation loss = 0.062 (acc: 1.000)test loss = 0.055 (acc: 1.000)
# Epoch 146: train loss = 0.095 (acc: 0.956), validation loss = 0.062 (acc: 1.000)test loss = 0.054 (acc: 1.000)
# Epoch 147: train loss = 0.095 (acc: 0.956), validation loss = 0.062 (acc: 1.000)test loss = 0.054 (acc: 1.000)
# Epoch 148: train loss = 0.095 (acc: 0.956), validation loss = 0.061 (acc: 1.000)test loss = 0.054 (acc: 1.000)
# Epoch 149: train loss = 0.095 (acc: 0.956), validation loss = 0.061 (acc: 1.000)test loss = 0.053 (acc: 1.000)
# Epoch 150: train loss = 0.094 (acc: 0.956), validation loss = 0.061 (acc: 1.000)test loss = 0.053 (acc: 1.000)
# Epoch 151: train loss = 0.094 (acc: 0.956), validation loss = 0.061 (acc: 1.000)test loss = 0.053 (acc: 1.000)
# Epoch 152: train loss = 0.094 (acc: 0.956), validation loss = 0.060 (acc: 1.000)test loss = 0.052 (acc: 1.000)
# Epoch 153: train loss = 0.094 (acc: 0.956), validation loss = 0.060 (acc: 1.000)test loss = 0.052 (acc: 1.000)
# Epoch 154: train loss = 0.093 (acc: 0.956), validation loss = 0.060 (acc: 1.000)test loss = 0.052 (acc: 1.000)
# Epoch 155: train loss = 0.093 (acc: 0.956), validation loss = 0.060 (acc: 1.000)test loss = 0.051 (acc: 1.000)
# Epoch 156: train loss = 0.093 (acc: 0.956), validation loss = 0.059 (acc: 1.000)test loss = 0.051 (acc: 1.000)
# Epoch 157: train loss = 0.093 (acc: 0.956), validation loss = 0.059 (acc: 1.000)test loss = 0.051 (acc: 1.000)
# Epoch 158: train loss = 0.092 (acc: 0.956), validation loss = 0.059 (acc: 1.000)test loss = 0.050 (acc: 1.000)
# Epoch 159: train loss = 0.092 (acc: 0.956), validation loss = 0.059 (acc: 1.000)test loss = 0.050 (acc: 1.000)
# Epoch 160: train loss = 0.092 (acc: 0.956), validation loss = 0.058 (acc: 1.000)test loss = 0.050 (acc: 1.000)
# Epoch 161: train loss = 0.092 (acc: 0.956), validation loss = 0.058 (acc: 1.000)test loss = 0.049 (acc: 1.000)
# Epoch 162: train loss = 0.092 (acc: 0.956), validation loss = 0.058 (acc: 1.000)test loss = 0.049 (acc: 1.000)
# Epoch 163: train loss = 0.091 (acc: 0.956), validation loss = 0.058 (acc: 1.000)test loss = 0.049 (acc: 1.000)
# Epoch 164: train loss = 0.091 (acc: 0.956), validation loss = 0.058 (acc: 1.000)test loss = 0.048 (acc: 1.000)
# Epoch 165: train loss = 0.091 (acc: 0.956), validation loss = 0.057 (acc: 1.000)test loss = 0.048 (acc: 1.000)
# Epoch 166: train loss = 0.091 (acc: 0.956), validation loss = 0.057 (acc: 1.000)test loss = 0.048 (acc: 1.000)
# Epoch 167: train loss = 0.091 (acc: 0.956), validation loss = 0.057 (acc: 1.000)test loss = 0.048 (acc: 1.000)
# Epoch 168: train loss = 0.090 (acc: 0.956), validation loss = 0.057 (acc: 1.000)test loss = 0.047 (acc: 1.000)
# Epoch 169: train loss = 0.090 (acc: 0.956), validation loss = 0.057 (acc: 1.000)test loss = 0.047 (acc: 1.000)
# Epoch 170: train loss = 0.090 (acc: 0.956), validation loss = 0.056 (acc: 1.000)test loss = 0.047 (acc: 1.000)
# Epoch 171: train loss = 0.090 (acc: 0.956), validation loss = 0.056 (acc: 1.000)test loss = 0.047 (acc: 1.000)
# Epoch 172: train loss = 0.090 (acc: 0.956), validation loss = 0.056 (acc: 1.000)test loss = 0.046 (acc: 1.000)
# Epoch 173: train loss = 0.089 (acc: 0.956), validation loss = 0.056 (acc: 1.000)test loss = 0.046 (acc: 1.000)
# Epoch 174: train loss = 0.089 (acc: 0.956), validation loss = 0.056 (acc: 1.000)test loss = 0.046 (acc: 1.000)
# Epoch 175: train loss = 0.089 (acc: 0.956), validation loss = 0.055 (acc: 1.000)test loss = 0.045 (acc: 1.000)
# Epoch 176: train loss = 0.089 (acc: 0.956), validation loss = 0.055 (acc: 1.000)test loss = 0.045 (acc: 1.000)
# Epoch 177: train loss = 0.089 (acc: 0.956), validation loss = 0.055 (acc: 1.000)test loss = 0.045 (acc: 1.000)
# Epoch 178: train loss = 0.089 (acc: 0.956), validation loss = 0.055 (acc: 1.000)test loss = 0.045 (acc: 1.000)
# Epoch 179: train loss = 0.088 (acc: 0.956), validation loss = 0.055 (acc: 1.000)test loss = 0.044 (acc: 1.000)
# Epoch 180: train loss = 0.088 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.044 (acc: 1.000)
# Epoch 181: train loss = 0.088 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.044 (acc: 1.000)
# Epoch 182: train loss = 0.088 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.044 (acc: 1.000)
# Epoch 183: train loss = 0.088 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.043 (acc: 1.000)
# Epoch 184: train loss = 0.088 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.043 (acc: 1.000)
# Epoch 185: train loss = 0.087 (acc: 0.956), validation loss = 0.054 (acc: 1.000)test loss = 0.043 (acc: 1.000)
# Epoch 186: train loss = 0.087 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.043 (acc: 1.000)
# Epoch 187: train loss = 0.087 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.043 (acc: 1.000)
# Epoch 188: train loss = 0.087 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.042 (acc: 1.000)
# Epoch 189: train loss = 0.087 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.042 (acc: 1.000)
# Epoch 190: train loss = 0.087 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.042 (acc: 1.000)
# Epoch 191: train loss = 0.086 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.042 (acc: 1.000)
# Epoch 192: train loss = 0.086 (acc: 0.956), validation loss = 0.053 (acc: 1.000)test loss = 0.041 (acc: 1.000)
# Epoch 193: train loss = 0.086 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.041 (acc: 1.000)
# Epoch 194: train loss = 0.086 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.041 (acc: 1.000)
# Epoch 195: train loss = 0.086 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.041 (acc: 1.000)
# Epoch 196: train loss = 0.086 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.041 (acc: 1.000)
# Epoch 197: train loss = 0.086 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.040 (acc: 1.000)
# Epoch 198: train loss = 0.085 (acc: 0.956), validation loss = 0.052 (acc: 1.000)test loss = 0.040 (acc: 1.000)
# Epoch 199: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.040 (acc: 1.000)
# Epoch 200: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.040 (acc: 1.000)
# Epoch 201: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 202: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 203: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 204: train loss = 0.085 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 205: train loss = 0.084 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 206: train loss = 0.084 (acc: 0.956), validation loss = 0.051 (acc: 1.000)test loss = 0.039 (acc: 1.000)
# Epoch 207: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.038 (acc: 1.000)
# Epoch 208: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.038 (acc: 1.000)
# Epoch 209: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.038 (acc: 1.000)
# Epoch 210: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.038 (acc: 1.000)
# Epoch 211: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.038 (acc: 1.000)
# Epoch 212: train loss = 0.084 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 213: train loss = 0.083 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 214: train loss = 0.083 (acc: 0.956), validation loss = 0.050 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 215: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 216: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 217: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.037 (acc: 1.000)
# Epoch 218: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 219: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 220: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 221: train loss = 0.083 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 222: train loss = 0.082 (acc: 0.956), validation loss = 0.049 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 223: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.036 (acc: 1.000)
# Epoch 224: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 225: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 226: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 227: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 228: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 229: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.035 (acc: 1.000)
# Epoch 230: train loss = 0.082 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 231: train loss = 0.081 (acc: 0.956), validation loss = 0.048 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 232: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 233: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 234: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 235: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 236: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.034 (acc: 1.000)
# Epoch 237: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 238: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 239: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 240: train loss = 0.081 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 241: train loss = 0.080 (acc: 0.956), validation loss = 0.047 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 242: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 243: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.033 (acc: 1.000)
# Epoch 244: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 245: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 246: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 247: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 248: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 249: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 250: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.032 (acc: 1.000)
# Epoch 251: train loss = 0.080 (acc: 0.956), validation loss = 0.046 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 252: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 253: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 254: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 255: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 256: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 257: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 258: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.031 (acc: 1.000)
# Epoch 259: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 260: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 261: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 262: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 263: train loss = 0.079 (acc: 0.956), validation loss = 0.045 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 264: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 265: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 266: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.030 (acc: 1.000)
# Epoch 267: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 268: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 269: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 270: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 271: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 272: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 273: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 274: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 275: train loss = 0.078 (acc: 0.956), validation loss = 0.044 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 276: train loss = 0.078 (acc: 0.956), validation loss = 0.043 (acc: 1.000)test loss = 0.029 (acc: 1.000)
# Epoch 277: train loss = 0.078 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 278: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 279: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 280: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 281: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 282: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 283: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 284: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 285: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.028 (acc: 1.000)
# Epoch 286: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 287: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 288: train loss = 0.077 (acc: 0.967), validation loss = 0.043 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 289: train loss = 0.077 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 290: train loss = 0.077 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 291: train loss = 0.077 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 292: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 293: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 294: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 295: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 296: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.027 (acc: 1.000)
# Epoch 297: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 298: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 299: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 300: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 301: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 302: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 303: train loss = 0.076 (acc: 0.967), validation loss = 0.042 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 304: train loss = 0.076 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 305: train loss = 0.076 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 306: train loss = 0.076 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 307: train loss = 0.076 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.026 (acc: 1.000)
# Epoch 308: train loss = 0.076 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 309: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 310: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 311: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 312: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 313: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 314: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 315: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 316: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 317: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 318: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 319: train loss = 0.075 (acc: 0.967), validation loss = 0.041 (acc: 1.000)test loss = 0.025 (acc: 1.000)
# Epoch 320: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 321: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 322: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 323: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 324: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 325: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 326: train loss = 0.075 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 327: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 328: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 329: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 330: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 331: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 332: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 333: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.024 (acc: 1.000)
# Epoch 334: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 335: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 336: train loss = 0.074 (acc: 0.967), validation loss = 0.040 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 337: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 338: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 339: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 340: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 341: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 342: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 343: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 344: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 345: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 346: train loss = 0.074 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 347: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 348: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.023 (acc: 1.000)
# Epoch 349: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 350: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 351: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 352: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 353: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 354: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 355: train loss = 0.073 (acc: 0.967), validation loss = 0.039 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 356: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 357: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 358: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 359: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 360: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 361: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 362: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 363: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 364: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.022 (acc: 1.000)
# Epoch 365: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 366: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 367: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 368: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 369: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 370: train loss = 0.073 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 371: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 372: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 373: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 374: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 375: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 376: train loss = 0.072 (acc: 0.967), validation loss = 0.038 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 377: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 378: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 379: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 380: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 381: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 382: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.021 (acc: 1.000)
# Epoch 383: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 384: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 385: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 386: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 387: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 388: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 389: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 390: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 391: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 392: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 393: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 394: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 395: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 396: train loss = 0.072 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 397: train loss = 0.071 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 398: train loss = 0.071 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 399: train loss = 0.071 (acc: 0.967), validation loss = 0.037 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 400: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 401: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 402: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.020 (acc: 1.000)
# Epoch 403: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 404: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 405: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 406: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 407: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 408: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 409: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 410: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 411: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 412: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 413: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 414: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 415: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 416: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 417: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 418: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 419: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 420: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 421: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 422: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 423: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 424: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 425: train loss = 0.071 (acc: 0.967), validation loss = 0.036 (acc: 1.000)test loss = 0.019 (acc: 1.000)
# Epoch 426: train loss = 0.071 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 427: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 428: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 429: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 430: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 431: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# Epoch 432: train loss = 0.070 (acc: 0.967), validation loss = 0.035 (acc: 1.000)test loss = 0.018 (acc: 1.000)
# ...
# Epoch 856: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 857: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 858: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 859: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 860: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 861: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 862: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 863: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 864: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 865: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 866: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 867: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 868: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 869: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 870: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 871: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 872: train loss = 0.064 (acc: 0.978), validation loss = 0.027 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 873: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 874: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 875: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 876: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 877: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 878: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 879: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 880: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 881: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 882: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 883: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 884: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 885: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 886: train loss = 0.064 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 887: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 888: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 889: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 890: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 891: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 892: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 893: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 894: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 895: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 896: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 897: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 898: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 899: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 900: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 901: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 902: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 903: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 904: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 905: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 906: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 907: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 908: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 909: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 910: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 911: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 912: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 913: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 914: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 915: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 916: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 917: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 918: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 919: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 920: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 921: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 922: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 923: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 924: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 925: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 926: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 927: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 928: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 929: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 930: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 931: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 932: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 933: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 934: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 935: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 936: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 937: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 938: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 939: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 940: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 941: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 942: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 943: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 944: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 945: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 946: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 947: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 948: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 949: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 950: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 951: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 952: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 953: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 954: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 955: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 956: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 957: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 958: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 959: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 960: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 961: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 962: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 963: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 964: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 965: train loss = 0.063 (acc: 0.978), validation loss = 0.026 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 966: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 967: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 968: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 969: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 970: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 971: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 972: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 973: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 974: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 975: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 976: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 977: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 978: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 979: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 980: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 981: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 982: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 983: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 984: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 985: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 986: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 987: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 988: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 989: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 990: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 991: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 992: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 993: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 994: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 995: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 996: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 997: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 998: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)
# Epoch 999: train loss = 0.063 (acc: 0.978), validation loss = 0.025 (acc: 1.000)test loss = 0.012 (acc: 1.000)

# %%
import matplotlib.pyplot as plt

plt.plot(range(1000), boosted_test_loss, alpha=0.5)
plt.plot(range(1000), boosted_val_loss, alpha=0.5)
plt.plot(range(1000), boosted_train_loss)
plt.xlabel("Liczba Epoch")
plt.ylabel("Funkcja Loss")
plt.legend(["Loss zbioru testowego", "Loss zbioru walidacyjnego", "Loss zbioru traningowego"])

plt.show()


plt.plot(range(1000), boosted_test_acc, alpha=0.5)
plt.plot(range(1000), boosted_val_acc, alpha=0.5)
plt.plot(range(1000), boosted_train_acc)
plt.xlabel("Liczba Epoch")
plt.ylabel("Metryka Accuracy")
plt.ylim([0,1.05])
plt.legend(["Accuracy zbioru testowego", "Accuracy zbioru walidacyjnego", "Accuracys zbioru traningowego"])

plt.show()

plt.plot(range(50), boosted_test_loss[:50], alpha=0.5)
plt.plot(range(50), boosted_val_loss[:50], alpha=0.5)
plt.plot(range(50), boosted_train_loss[:50])
plt.xlabel("Liczba Epoch")
plt.ylabel("Funkcja Loss")
plt.legend(["Loss zbioru testowego", "Loss zbioru walidacyjnego", "Loss zbioru traningowego"])

plt.show()


plt.plot(range(50), boosted_test_acc[:50], alpha=0.5)
plt.plot(range(50), boosted_val_acc[:50], alpha=0.5)
plt.plot(range(50), boosted_train_acc[:50])
plt.xlabel("Liczba Epoch")
plt.ylabel("Metryka Accuracy")
plt.ylim([0,1.05])
plt.legend(["Accuracy zbioru testowego", "Accuracy zbioru walidacyjnego", "Accuracys zbioru traningowego"])

plt.show()

# %% [markdown]
# ***Uzupełnij*** funkcję `fit`, aby ta mogła logować metryki (*loss*, *accuracy*) per epokę. Po zebraniu historii uczenia ***przedstaw*** następujące wykresy:
# - Wykres wartości funkcji kosztu w zależności od epoki uczenia dla zbioru uczącego i testowego
# - Wykres wartości metryki *accuracy* w zależności od epoki uczenia dla zbioru uczącego i testowego
#
# Metryki dla obu zbiorów przedstaw na jednym wykresie jako serie. ***Uzupełnij*** etykiety osi i tytuły wykresów.

# %% [markdown]
# ***Popraw*** model, tak aby otrzymać dokładność na zbiorze testowym wynoszącą co najmniej 90%. W tym celu dobierz odpowiedni współczynnik uczenia i liczbę epok.
# Do porównania badanych hiperparametrów użyj zbioru walidacyjnego. Podziel zbiór testowy na dwie równe części, jeden który będzie służyć do walidacji hiperparametrów, a drugi, który będzie służył do ewaluacji znalezionej najlepszej pary hiperparametrów. W tym celu możesz wykorzystać funkcję `torch.utils.data.random_split` z ustawionym parametrem `generator=torch.Generator().manual_seed(1)`. Przedstaw równiez wykresy o których mowa punkcie powyżej tym razem z uwzględniem trzech zbiorów (uczącego, walidacyjnego i testowego)
